# %% [markdown]
# <a href="https://colab.research.google.com/github/ZykinaViktoriya/Python_for_analytics/blob/main/%D0%A2%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D0%BE%D0%B5_%D0%B7%D0%B0%D0%BA%D0%B0%D0%B7%D1%8B_%D0%B2%D0%BE%D0%B7%D0%B2%D1%80%D0%B0%D1%82%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Статистика интернет-магазина

# %%
import pandas as pd

# %% [markdown]
# ## Таблица заказов
# - Сколько у нас данных и каковы их основные свойства?
# - Какие категории и регионы есть в данных?
# - Как распределены данные по этим столбцам?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sales = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sales_v2023-07-09.csv')
sales.head(10)
# Out:
#    order_id        date  customer_id         category               region  \
# 0  59570135  2017-10-16          512   Одежда и обувь  Ставропольский край
# 1  16578697  2017-07-18          512   Одежда и обувь  Ставропольский край
# 2  46943601  2017-07-05          512  Бытовая техника  Ставропольский край
# 3  42436035  2017-02-18          512    Спорт и отдых  Ставропольский край
# 4  49798299  2017-09-08          512          Красота  Ставропольский край
# 5  85282012  2017-01-01          512           Аптека  Ставропольский край
# 6  86441447  2017-07-04          513    Спорт и отдых   Московская область
# 7   3468527  2017-05-31          513           Аптека   Московская область
# 8  82105305  2017-03-30          513    Спорт и отдых   Московская область
# 9  23201528  2017-04-22          513           Аптека   Московская область
#
#    sales  quantity  discount
# 0   1301         2      0.00
# 1   3530         4      0.05
# 2   5773         1      0.10
# 3   4723         3      0.03
# 4   1936         3      0.00
# 5    266         1      0.03
# 6   7129         3      0.00
# 7    105         3      0.03
# 8  18285         3      0.05
# 9   1743         3      0.00

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1554192 entries, 0 to 1554191
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   order_id     1554192 non-null  int64
#  1   date         1554192 non-null  object
#  2   customer_id  1554192 non-null  int64
#  3   category     1554192 non-null  object
#  4   region       1554192 non-null  object
#  5   sales        1554192 non-null  int64
#  6   quantity     1554192 non-null  int64
#  7   discount     1554192 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 94.9+ MB

# %%
sales.describe()
# Out:
#            order_id   customer_id         sales      quantity      discount
# count  2.197115e+06  2.197115e+06  2.197115e+06  2.197115e+06  2.197115e+06
# mean   5.001083e+07  2.003929e+05  4.087037e+03  2.500769e+00  2.997716e-02
# std    2.887257e+07  1.155010e+05  4.395952e+03  1.037031e+00  3.649924e-02
# min    2.800000e+01  5.120000e+02  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.498756e+07  1.003080e+05  1.131000e+03  2.000000e+00  0.000000e+00
# 50%    5.004405e+07  2.002640e+05  2.503000e+03  2.000000e+00  0.000000e+00
# 75%    7.501209e+07  3.004370e+05  5.257000e+03  3.000000e+00  5.000000e-02
# max    9.999996e+07  4.005110e+05  4.187300e+04  8.000000e+00  1.000000e-01

# %%
# диапазон дат

min(sales['date']), max(sales['date'])
# Out:
# ('2017-02-26', '2019-12-04')

# %%
sales.date
# Out:
# 0          2017-10-16
# 1          2017-07-18
# 2          2017-07-05
# 3          2017-02-18
# 4          2017-09-08
#               ...
# 1554187    2019-07-12
# 1554188    2019-10-11
# 1554189    2019-05-08
# 1554190    2019-05-02
# 1554191    2019-03-27
# Name: date, Length: 1554192, dtype: object

# %%
# уникальные категории

sales['category'].unique()
# Out:
# array(['Одежда и обувь', 'Бытовая техника', 'Спорт и отдых', 'Красота',
#        'Аптека', 'Продукты питания', 'Дача и сад', 'Мебель'], dtype=object)

# %%
# распределение количества строк по категориям

sales['category'].value_counts()
# Out:
# Продукты питания    382293
# Одежда и обувь      290961
# Спорт и отдых       255183
# Аптека              217553
# Дача и сад          187732
# Бытовая техника     127254
# Красота              63975
# Мебель               29241
# Name: category, dtype: int64

# %%
# тоже самое в процентах
sales['category'].value_counts(normalize=True)
# Out:
# Продукты питания    0.239776
# Одежда и обувь      0.199944
# Спорт и отдых       0.159744
# Аптека              0.140117
# Дача и сад          0.120451
# Бытовая техника     0.080099
# Красота             0.039876
# Мебель              0.019993
# Name: category, dtype: float64

# %% [markdown]
# ### Как задавать фильтры

# %%
# через метод query

sales.query('category=="Аптека"')
# Out:
#          order_id        date  customer_id category               region  \
# 10       61810289  2018-03-05          514   Аптека     Хабаровский край
# 21       84074301  2017-12-23          516   Аптека    Иркутская область
# 26       19057148  2018-03-31          517   Аптека   Московская область
# 34       75486082  2018-01-01          519   Аптека   Смоленская область
# 35       45972539  2018-05-23          519   Аптека   Смоленская область
# ...           ...         ...          ...      ...                  ...
# 2197071  83720359  2018-04-14       400503   Аптека  Ставропольский край
# 2197073   8582511  2017-12-01       400504   Аптека   Смоленская область
# 2197079  81657427  2018-03-13       400506   Аптека   Смоленская область
# 2197083  26755201  2018-05-18       400507   Аптека    Красноярский край
# 2197109  76250033  2018-06-09       400509   Аптека   Московская область
#
#          sales  quantity  discount
# 10        1029         2      0.05
# 21        3193         4      0.10
# 26         911         3      0.10
# 34        1627         2      0.00
# 35        1112         3      0.03
# ...        ...       ...       ...
# 2197071    706         2      0.10
# 2197073    969         2      0.00
# 2197079   2006         3      0.10
# 2197083    855         3      0.00
# 2197109   2366         3      0.00
#
# [307853 rows x 8 columns]

# %%
# индексированный фильтр

data_amur = sales[sales['region'] == 'Амурская область']
data_amur.head()
# Out:
#     order_id        date  customer_id          category            region  \
# 44  52369577  2017-10-07          518    Одежда и обувь  Амурская область
# 45   2430224  2017-11-16          518    Одежда и обувь  Амурская область
# 70   2527242  2017-03-10          522            Аптека  Амурская область
# 71  43566555  2017-07-01          522  Продукты питания  Амурская область
# 72  36151588  2017-07-24          522   Бытовая техника  Амурская область
#
#     sales  quantity  discount
# 44   3877         2       0.0
# 45   1859         1       0.0
# 70    685         1       0.0
# 71   3666         2       0.0
# 72   9666         2       0.0

# %%
# если надо сразу несколько регионов отфильтровать

data_east = sales[sales['region'].isin(['Амурская область', 'Хабаровский край', 'Приморский край',
                                        'Иркутская область', 'Красноярский край'])]
data_east.sample(15)
# Out:
#          order_id        date  customer_id          category  \
# 394998   65109442  2017-03-20        76711  Продукты питания
# 638332    6731798  2018-12-19        22283           Красота
# 20281    30785463  2017-05-14         4430    Одежда и обувь
# 1232111  15960801  2018-09-06        33948            Аптека
# 1103308  29792353  2019-03-05         7479            Аптека
# 239420   64562804  2017-04-06        46715        Дача и сад
# 416805   62742087  2017-06-01        80935            Аптека
# 704020   89691010  2018-09-02        34206    Одежда и обувь
# 650333   61517617  2018-06-14        24442     Спорт и отдых
# 682618   67291565  2017-12-13        30295            Аптека
# 198923     550408  2017-08-08        38909   Бытовая техника
# 1224478  52928798  2019-01-14        32400            Аптека
# 567766   19607787  2018-08-11         9465     Спорт и отдых
# 1256319  18779256  2019-10-12        38887    Одежда и обувь
# 590074   85794513  2018-05-06        13500        Дача и сад
#
#                     region  sales  quantity  discount
# 394998     Приморский край   1063         3      0.00
# 638332    Хабаровский край    248         2      0.00
# 20281    Иркутская область   1665         2      0.00
# 1232111  Красноярский край   1912         2      0.00
# 1103308  Красноярский край    463         2      0.00
# 239420   Иркутская область  10964         2      0.05
# 416805   Иркутская область   2650         1      0.00
# 704020    Хабаровский край   2005         3      0.00
# 650333    Хабаровский край   2263         3      0.00
# 682618    Хабаровский край    822         2      0.00
# 198923    Амурская область   7810         1      0.00
# 1224478  Иркутская область      7         3      0.10
# 567766    Амурская область   2869         2      0.00
# 1256319   Хабаровский край   2274         3      0.00
# 590074   Красноярский край   3946         2      0.03

# %%
# несколько фильтров
sales[(sales['region']=='Хабаровский край') & (sales['discount'] > 0.05)]
# Out:
#          order_id        date  customer_id          category  \
# 14       70774121  2017-07-02          514           Красота
# 27       85885236  2017-01-03          516            Аптека
# 28       94577895  2017-08-05          516    Одежда и обувь
# 33       47980118  2017-06-19          516  Продукты питания
# 62       69800348  2017-04-15          521        Дача и сад
# ...           ...         ...          ...               ...
# 1553989  41008928  2019-03-17       100471        Дача и сад
# 1553991  58475920  2019-03-20       100471  Продукты питания
# 1554122  42585076  2019-09-21       100497    Одежда и обувь
# 1554142  60089015  2019-01-04       100500     Спорт и отдых
# 1554144  42911034  2019-04-20       100500     Спорт и отдых
#
#                    region  sales  quantity  discount
# 14       Хабаровский край   1281         5       0.1
# 27       Хабаровский край    836         2       0.1
# 28       Хабаровский край   1210         1       0.1
# 33       Хабаровский край   1587         3       0.1
# 62       Хабаровский край   2203         1       0.1
# ...                   ...    ...       ...       ...
# 1553989  Хабаровский край    945         1       0.1
# 1553991  Хабаровский край    552         3       0.1
# 1554122  Хабаровский край   2573         3       0.1
# 1554142  Хабаровский край   4567         4       0.1
# 1554144  Хабаровский край   2031         2       0.1
#
# [29156 rows x 8 columns]

# %% [markdown]
# ### Распределение продаж по категориям
# Для каждой категории посчитаем сумму продаж по столбцу sales

# %%
sales.groupby('category').agg({'sales': 'sum'})
# Out:
#                        sales
# category
# Аптека             253901402
# Бытовая техника   1040194206
# Дача и сад        1095424217
# Красота             74717089
# Мебель             273758727
# Одежда и обувь     678825888
# Продукты питания   891545007
# Спорт и отдых     2084228509

# %% [markdown]
# ### Самые активные покупатели
# Действуем аналогично, только группировка по ID покупателя + добавим сортировку результата по убыванию.

# %%
sales.groupby('customer_id').agg({'sales': 'sum'}).sort_values('sales', ascending=False).head()
# Out:
#               sales
# customer_id
# 62131        119436
# 9430         114258
# 63102        107431
# 214725       107310
# 50716        107233

# %%
# как получить топ-10 самых активных покупателей

top_customers = sales.groupby('customer_id').agg({'sales': 'sum'}).sort_values('sales', ascending=False).head().index
top_customers
# Out:
# Int64Index([5706, 5599, 18767, 93988, 99784], dtype='int64', name='customer_id')

# %% [markdown]
# ## Таблица возвратов

# %%
returns = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/returns_v2023-07-09.csv')
returns.head()
# Out:
#    order_id  return
# 0  14186940       1
# 1  46863464       0
# 2  98992195       1
# 3  29193654       1
# 4  63339281       0

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1639021 entries, 0 to 1639020
# Data columns (total 2 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   order_id  1639021 non-null  int64
#  1   return    1639021 non-null  int64
# dtypes: int64(2)
# memory usage: 25.0 MB

# %% [markdown]
# Объединяем таблицы продаж и возвратов

# %%
# %%time

joined = sales.merge(returns, on='order_id')  # how - тип объединения (left, right)
joined.head()
# Out:
# CPU times: user 770 ms, sys: 239 ms, total: 1.01 s
# Wall time: 1.02 s
#    order_id        date  customer_id          category                 region  \
# 0  59570135  2017-10-16          512    Одежда и обувь    Ставропольский край
# 1  96798611  2017-09-10          514  Продукты питания       Хабаровский край
# 2  63656156  2017-02-20          528     Спорт и отдых  Ленинградская область
# 3  64457545  2017-05-13          536     Спорт и отдых       Амурская область
# 4  79445775  2017-02-21          543        Дача и сад       Амурская область
#
#    sales  quantity  discount  return
# 0   1301         2      0.00       0
# 1   2484         1      0.03       0
# 2  16743         2      0.10       0
# 3   9716         2      0.05       1
# 4   2577         3      0.00       0

# %% [markdown]
# Построим сводную таблицу, где для каждой категории посмотрим количество строк для возвратов (1) и успешных заказов (0).

# %%
pivot = joined.pivot_table(index='category', columns='return', values='sales', aggfunc='count')
pivot
# Out:
# return               0     1
# category
# Аптека            2720   912
# Бытовая техника   1627   512
# Дача и сад        2366   803
# Красота            799   279
# Мебель             374   116
# Одежда и обувь    3633  1218
# Продукты питания  4785  1553
# Спорт и отдых     3124  1051

# %% [markdown]
# Считаем долю возвратов

# %%
pivot['returns_share'] = pivot[1] / (pivot[0] + pivot[1])
pivot
# Out:
# return               0     1  returns_share
# category
# Аптека            2720   912       0.251101
# Бытовая техника   1627   512       0.239364
# Дача и сад        2366   803       0.253392
# Красота            799   279       0.258813
# Мебель             374   116       0.236735
# Одежда и обувь    3633  1218       0.251082
# Продукты питания  4785  1553       0.245030
# Спорт и отдых     3124  1051       0.251737

# %%
# как сохранить результат

pivot.to_csv('result.csv')

# %%
pivot.to_excel('result.xlsx')

# %%
data_new = sales.merge(returns, on='order_id')
data_new
# Out:
#        order_id        date  customer_id          category  \
# 0      59570135  2017-10-16          512    Одежда и обувь
# 1      96798611  2017-09-10          514  Продукты питания
# 2      63656156  2017-02-20          528     Спорт и отдых
# 3      64457545  2017-05-13          536     Спорт и отдых
# 4      79445775  2017-02-21          543        Дача и сад
# ...         ...         ...          ...               ...
# 25867   5034602  2018-12-25       100435            Аптека
# 25868  57107781  2019-08-22       100466    Одежда и обувь
# 25869  89725136  2019-05-22       100468  Продукты питания
# 25870  70976569  2019-04-30       100469  Продукты питания
# 25871  42234292  2019-04-25       100478  Продукты питания
#
#                       region  sales  quantity  discount  return
# 0        Ставропольский край   1301         2      0.00       0
# 1           Хабаровский край   2484         1      0.03       0
# 2      Ленинградская область  16743         2      0.10       0
# 3           Амурская область   9716         2      0.05       1
# 4           Амурская область   2577         3      0.00       0
# ...                      ...    ...       ...       ...     ...
# 25867       Амурская область    500         4      0.00       0
# 25868   Владимирская область   3769         5      0.00       1
# 25869      Красноярский край    917         1      0.00       0
# 25870     Краснодарский край    466         2      0.10       1
# 25871        Приморский край   3398         2      0.00       0
#
# [25872 rows x 9 columns]

# %%
filter = data_new[data_new['category'].isin(['Бытовая техника', 'Одежда и обувь'])]
filter.sample(15)
# Out:
#        order_id        date  customer_id         category  \
# 9457   76061049  2018-10-15        10039  Бытовая техника
# 12526  39920483  2019-01-04        43375   Одежда и обувь
# 7081    9184233  2017-08-29        82087  Бытовая техника
# 23649    563890  2019-08-03        72840  Бытовая техника
# 13430  73239620  2018-05-21        53130   Одежда и обувь
# 13561  43789261  2018-10-01        54278   Одежда и обувь
# 722    94279517  2018-02-11         9018   Одежда и обувь
# 11563  40134081  2018-06-06        32967  Бытовая техника
# 14104   2862054  2018-05-28        60284   Одежда и обувь
# 21160  10634327  2019-05-01        41796   Одежда и обувь
# 20409  95423772  2019-07-15        32411   Одежда и обувь
# 3172   54931251  2017-06-23        37111  Бытовая техника
# 25019   1930708  2019-07-03        89928   Одежда и обувь
# 24726  84957053  2019-06-29        86237   Одежда и обувь
# 646    79612626  2017-10-01         8140   Одежда и обувь
#
#                       region  sales  quantity  discount  return
# 9457        Амурская область   7996         2      0.05       0
# 12526     Московская область     54         4      0.10       0
# 7081      Московская область  11732         3      0.00       0
# 23649       Амурская область  16690         2      0.05       0
# 13430     Краснодарский край   1606         3      0.00       0
# 13561   Владимирская область   2608         3      0.00       0
# 722      Ставропольский край   1233         2      0.00       0
# 11563    Ставропольский край  18301         2      0.05       0
# 14104      Красноярский край    479         1      0.00       0
# 21160  Ленинградская область    877         3      0.05       0
# 20409        Приморский край   1942         3      0.00       1
# 3172        Хабаровский край   5165         1      0.05       0
# 25019       Хабаровский край    589         2      0.00       1
# 24726     Московская область   3547         3      0.10       0
# 646       Московская область    870         2      0.00       0

# %%
region_sales = filter.groupby('region').agg({'sales': 'sum'})
region_sales.sort_values('sales', ascending=False)
# Out:
#                          sales
# region
# Московская область     3943161
# Амурская область       3730662
# Ленинградская область  3333865
# Хабаровский край       3322660
# Иркутская область      2457319
# Приморский край        2324665
# Краснодарский край     2235671
# Ставропольский край    1979851
# Владимирская область   1839444
# Красноярский край      1590474
# Смоленская область     1532887

# %%
pivot_filtered = filter.pivot_table(index='region', columns='return', values='sales', aggfunc='sum')
pivot
pivot_filtered['returns_share'] = pivot_filtered[1] / (pivot_filtered[0] + pivot_filtered[1])
pivot_filtered
# Out:
# return                       0        1  returns_share
# region
# Амурская область       2892601   838061       0.224641
# Владимирская область   1422204   417240       0.226829
# Иркутская область      1827321   629998       0.256376
# Краснодарский край     1770391   465280       0.208116
# Красноярский край      1204665   385809       0.242575
# Ленинградская область  2601517   732348       0.219669
# Московская область     2933389  1009772       0.256082
# Приморский край        1644593   680072       0.292546
# Смоленская область     1222447   310440       0.202520
# Ставропольский край    1470250   509601       0.257394
# Хабаровский край       2580857   741803       0.223256
